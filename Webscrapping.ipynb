# %%
from Agnam import Manga

# %%
name = 'The Great Mage Returns After 4000 Years'
manga = Manga(name)
# manga = Manga()
# manga.search()
# Out:
# Success.

# %%
manga
# Out:
# {
#     "name": "The Great Mage Returns After 4000 Years",
#     "url_page": "https://readmanganato.com/manga-hu985229",
#     "logo": "https://avt.mkklcdnv6temp.com/7/f/21-1588309436.jpg",
#     "alternative": [
#         "4000년 만에 귀환한 대마도사"
#     ],
#     "authors": "Barnacle",
#     "status": "Ongoing",
#     "genres": [
#         "Action",
#         "Adventure",
#         "Fantasy"
#     ],
#     "chapters": [
#         {
#             "title": "Chapter 1",
#             "url": "https://readmanganato.com/manga-hu985229/chapter-1"
#         },
#         {
#             "title": "Chapter 2",
#             "url": "https://readmanganato.com/manga-hu985229/chapter-2"
#         },
#         {
#             "title": "Chapter 3",
#             "url": "https://readmanganato.com/manga-hu985229/chapter-3"
#         },
#         {
#             "title": "Chapter 4",
#             "url": "https://readmanganato.com/manga-hu985229/chapter-4"
#         },
#         {
# ...

# %%
# manga.display(manga.get_chapter(num=-1))

# %%
# !touch .gitignore
